# %% [markdown]
# What is the difference between hardware and software? Give one example of each.
#
# Hardware refers to the physical parts of a computer
# Example: Keyboard, mouse ( physical device you can touch)
#
# Software refers to the programs and instructions that tell the hardware what to do.
# Example: Microsoft Word, Excel (program used to create documents)
